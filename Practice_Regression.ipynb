# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import statsmodels.formula.api as smf

# %%
datas=pd.read_csv('NewspaperData.csv')

# %%
sns.boxplot(x='sunday',y='daily',data=data)

# %%
sns.distplot(data['sunday'])

# %%
sns.distplot(data['daily'])

# %%
sns.distplot(['sunday'])
sns.distplot(['daily'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-161233f78523> in <module>
# ----> 1 sns.distplot(['sunday'])
#       2 sns.distplot(['daily'])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     175
#     176     # Make a a 1-d float array
# --> 177     a = np.asarray(a, np.float)
#     178     if a.ndim > 1:
#     179         a = a.squeeze()
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'sunday'

# %%
sns.distplot(data['daily'],hist=False,rug=True)
sns.distplot(data['sunday'],hist=False,rug=True)

# %%
sns.relplot(x='sunday',y='daily',data=data)

# %%
sns.distplot(data['sunday'],hist=False,rug=True)
sns.distplot(data['daily'],hist=False,rug=True)

# %%
sns.rugplot(data['sunday'])

# %%
sns.regplot(x='sunday',y='daily',data=datas)

# %%
model=smf.ols('sunday~daily',data=datas).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           6.02e-19
# Time:                        23:49:33   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
model.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
(model.pvalues)
# Out:
# Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
(model.tvalues)
# Out:
# Intercept     0.386427
# daily        18.934840
# dtype: float64

# %%
#model is ready for the testing

# %%
newdata=pd.Series([300,400,500])

# %%
pred_data=pd.DataFrame(newdata,columns=['daily'])

# %%
model.predict(pred_data)
# Out:
# 0    415.750057
# 1    549.721533
# 2    683.693009
# dtype: float64

# %%
pred_data2=pd.DataFrame(newdata,columns=['daily'])

# %%
model.predict(pred_data2)
# Out:
# 0    415.750057
# 1    549.721533
# 2    683.693009
# dtype: float64
